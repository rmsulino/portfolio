# %% [markdown]
# # Teste de Conconi

# %%
import numpy
import pandas as pd
import sklearn.linear_model as lm
import matplotlib
import matplotlib.pyplot as plt

# %%
# Nome do arquivo contendo os dados
ARQUIVO = "conconi.csv"

# nome das colunas x e y
COLUNA_X = "speed"
COLUNA_Y = "media-hr"

# %%
dados = pd.read_csv(ARQUIVO, sep=';')

print("Dados coletados:")
print()
print(dados)
# Out:
# Dados coletados:
#
#    avg-pace  sec  speed  media-hr  max-hr
# 0     06:59  419   8.59       139     145
# 1     06:54  414   8.70       146     152
# 2     06:24  384   9.38       153     155
# 3     06:16  376   9.57       157     162
# 4     05:48  348  10.34       160     162
# 5     05:32  332  10.84       165     170
# 6     05:18  318  11.32       171     173
# 7     05:03  303  11.88       175     177
# 8     04:51  291  12.37       179     180
# 9     04:42  282  12.77       181     183
# 10    04:21  251  13.79       184     187
# 11    04:32  272  13.24       186     188
# 12    04:07  247  14.57       189     191

# %%
## Preparação do modelo de regressão linear

# %%
olm = lm.LinearRegression()

# %%
X = numpy.array(dati[COLUNA_X])[:, numpy.newaxis]
y = dati[COLUNA_Y]

# %% [markdown]
# ## Treinamento do modelo (Ordinary Least Squares)

# %%
olm.fit(X, y)
# Out:
# LinearRegression()

# %%
olm_score = olm.score(X, y)

print()
print("Score: %.3f" % olm_score)
# Out:
# Score: 0.957

# %% [markdown]
# ## Predição linear

# %%
yp = olm.predict(X)

# %% [markdown]
# ## Gráfico

# %%
plt.style.use('bmh')

# %%
plt.plot(X, y.values)
plt.plot(X, yp)

plt.title("Teste de Conconi")
plt.xlabel("Velocidade (km/h)")
plt.ylabel("Média FC")
plt.legend(["atual", "predição"], loc="lower right")
plt.annotate("Score=%.3f" % olm_score, xy=(X.min(), y.max()))
plt.grid('black')
plt.show()

# %% [markdown]
# # Resultado

# %% [markdown]
# ### O limiar anaeróbio é o ponto de inflexão onde a relação y = f(x) deixa de ser linear. No caso deste exemplo, aproximadamente em 13,5 km/h (+/- 0,5).
